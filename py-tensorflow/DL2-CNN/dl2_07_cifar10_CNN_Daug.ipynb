# %% [markdown]
# <a href="https://colab.research.google.com/github/hojoooon/PDM16/blob/main/py-tensorflow/DL2-CNN/dl2_07_cifar10_CNN_Daug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CNN model of cifar10 dataset**
# - Conv2D + FCN
#     * Conv2D : 2차원 합성곱 필터링 + 풀링(Pooling)
#     - > 2차원 필터로 영상을 대표하는 특징을 추출
#     * FCN : 1차원 완전연결신경망
#     - > Conv2D에서 추출된 대표 특징들을 이용하여 FCN으로 최종 학습 완료
#     * **Data augmentation**
#
# ***
# - ## Traget: **Find the best model**
# ***
#
# ![cnn_c4f5.png](https://raw.githubusercontent.com/Redwoods/Py/master//pdm2020/my-note/py-tensorflow/images/cnn_c4f5.png)

# %% [markdown]
# ## Search the best model of C4F5
# - callback
#     - Early stopping
#     - model checkpoint
# - Data augmentation

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print(tf.__version__)
# Out:
# 2.7.0

# %%
# import TF2 submodules
from tensorflow.keras import layers, models, callbacks

# %% [markdown]
# ## **데이터 로딩, 정규화**

# %%
from keras.datasets import cifar10

(X_train0, y_train0), (X_test0, y_test0) = cifar10.load_data()

# Reshape
# X_train = X_train0.reshape(60000,28,28,1)
# X_test = X_test0.reshape(10000,28,28,1)

# Normalization
X_train, X_test = X_train0/255.0, X_test0/255.0 # 정규화

print("X_train={0}".format(X_train.shape))
print("y_train={0}".format(y_train0.shape)) 
print("X_test={0}".format(X_test.shape))
print("y_test={0}".format(y_test0.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step
# X_train=(50000, 32, 32, 3)
# y_train=(50000, 1)
# X_test=(10000, 32, 32, 3)
# y_test=(10000, 1)

# %%
# One-Hot-Encoding
# Use function to_categorical() to do One-Hot-Encoding
# tf.keras.utils.to_categorical
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)
y_train.shape,y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %%
# y_train0.shape vs. y_train.shape
y_train0.shape, y_train.shape
# Out:
# ((50000, 1), (50000, 10))

# %% [markdown]
# ### Display cifar10 data
# - one random image
# - 10 representative images

# %%
# Code here!
# display one random image from the training set:
class_names =  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

idx = np.random.randint(0, X_train0.shape[0])
print(idx)
image = X_train0[idx]
plt.imshow(image) #, cmap=plt.get_cmap('gray'))
plt.title(class_names[y_train0[idx][0]])
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 21544

# %%
fig = plt.figure(figsize=(10,6))
num0_9 = np.unique(y_train0, return_index=True)[1]
images = X_train[num0_9]
for i in range(10):
    plt.subplot(2, 5, i+1)
    # num0_9 = X_train0[y_train0 == i]
    
    # print(num0_9.shape)
    # plt.imshow(num0_9[0]) 
    plt.imshow(images[i])
    plt.title(class_names[i])
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# data augmentation
# https://github.com/moritzhambach/Image-Augmentation-in-Keras-CIFAR-10-/blob/master/CNN%20with%20Image%20Augmentation%20(CIFAR10).ipynb
# set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
    #zoom_range=0.3
    )
datagen.fit(X_train)

# %%
BATCH_SIZE = 50
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=BATCH_SIZE):
    print(X_batch.shape, y_batch.shape)
    # create a grid of 5x10 images
    plt.figure(figsize=(13,13))
    for i in range(BATCH_SIZE):
        plt.subplot(5,10,i+1)
        plt.imshow(X_batch[i]) #, cmap=plt.get_cmap('gray'))
        plt.title(class_names[np.argmax(y_batch[i])])
        # show the plot
    plt.show()
    break
# Out:
# (50, 32, 32, 3) (50, 10)

# %% [markdown]
# # Design CNN

# %% [markdown]
# ### import models, layers, callbacks
# - models: Sequential
# - layers: Conv2D, MaxPool2D, Flatten
# - callbacks: ModelCheckpoint, EarlyStopping

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, TensorBoard
from keras import regularizers, optimizers

# %%
# 모델 구성
num_classes = 10
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=X_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(128, activation='elu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
opt_rms = keras.optimizers.RMSprop(learning_rate=0.001,decay=1e-6)

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)  # 5, 10, 20, 50

# %%
model.compile(loss='categorical_crossentropy',
        optimizer=opt_rms, # 'adam'
        metrics=['accuracy'])

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 68s 56ms/step - loss: 1.6013 - accuracy: 0.4583 - val_loss: 1.1892 - val_accuracy: 0.5890
# Epoch 2/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 1.1935 - accuracy: 0.6035 - val_loss: 1.2920 - val_accuracy: 0.5923
# Epoch 3/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 1.0550 - accuracy: 0.6604 - val_loss: 1.2902 - val_accuracy: 0.6389
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.9691 - accuracy: 0.6947 - val_loss: 0.9125 - val_accuracy: 0.7254
# Epoch 5/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.9050 - accuracy: 0.7215 - val_loss: 0.8739 - val_accuracy: 0.7489
# Epoch 6/500
# 1000/1000 [==============================] - 53s 52ms/step - loss: 0.8645 - accuracy: 0.7380 - val_loss: 0.8274 - val_accuracy: 0.7534
# Epoch 7/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.8239 - accuracy: 0.7559 - val_loss: 0.7361 - val_accuracy: 0.7877
# Epoch 8/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.8009 - accuracy: 0.7639 - val_loss: 0.7801 - val_accuracy: 0.7822
# Epoch 9/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.7736 - accuracy: 0.7768 - val_loss: 0.7530 - val_accuracy: 0.7896
# Epoch 10/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.7592 - accuracy: 0.7820 - val_loss: 0.9179 - val_accuracy: 0.7422
# Epoch 11/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.7384 - accuracy: 0.7920 - val_loss: 0.8387 - val_accuracy: 0.7741
# Epoch 12/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.7266 - accuracy: 0.7957 - val_loss: 0.8017 - val_accuracy: 0.7836
# Epoch 13/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.7159 - accuracy: 0.8003 - val_loss: 0.6765 - val_accuracy: 0.8190
# Epoch 14/500
# 1000/1000 [==============================] - 52s 51ms/step - loss: 0.7020 - accuracy: 0.8058 - val_loss: 0.6876 - val_accuracy: 0.8122
# Epoch 15/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6955 - accuracy: 0.8086 - val_loss: 0.8821 - val_accuracy: 0.7625
# Epoch 16/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6861 - accuracy: 0.8123 - val_loss: 0.6703 - val_accuracy: 0.8251
# Epoch 17/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6770 - accuracy: 0.8159 - val_loss: 0.6226 - val_accuracy: 0.8403
# Epoch 18/500
# 1000/1000 [==============================] - 52s 51ms/step - loss: 0.6714 - accuracy: 0.8178 - val_loss: 0.7468 - val_accuracy: 0.7969
# Epoch 19/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6622 - accuracy: 0.8228 - val_loss: 0.6405 - val_accuracy: 0.8376
# Epoch 20/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6583 - accuracy: 0.8228 - val_loss: 0.6818 - val_accuracy: 0.8197
# Epoch 21/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6506 - accuracy: 0.8263 - val_loss: 0.6745 - val_accuracy: 0.8245
# Epoch 22/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6454 - accuracy: 0.8285 - val_loss: 0.6548 - val_accuracy: 0.8330
# Epoch 00022: early stopping

# %%
model.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 3s 11ms/step - loss: 0.6548 - accuracy: 0.8330
# [0.6548215746879578, 0.8330000042915344]

# %% [markdown]
# ### cifar10 Daug best Model
# - cifar10_Daug_best_weights.017-0.8366.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_Daug_best_weights.017-0.8403.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 15ms/step - loss: 0.6226 - accuracy: 0.8403
# [0.622565746307373, 0.8403000235557556]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_Daug_best

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # import models, layers, callbacks

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # **CNN1 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c1f3 = tf.keras.models.Sequential([ 
    # tf.keras.layers.Flatten(input_shape=(28, 28)), 
    Conv2D(input_shape=(32,32,3), filters= 32,
            kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(10, activation='softmax')
])

cifar10_c1f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c1f3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 256)               2097408
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 2,132,490
# Trainable params: 2,132,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c1f3_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)    # patience=10, 25, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 53s 52ms/step - loss: 0.6671 - accuracy: 0.8202 - val_loss: 0.6500 - val_accuracy: 0.8332
# Epoch 2/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6697 - accuracy: 0.8209 - val_loss: 0.7143 - val_accuracy: 0.8188
# Epoch 3/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6602 - accuracy: 0.8239 - val_loss: 0.6589 - val_accuracy: 0.8279
# Epoch 4/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6495 - accuracy: 0.8288 - val_loss: 0.5932 - val_accuracy: 0.8460
# Epoch 5/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6503 - accuracy: 0.8267 - val_loss: 0.6345 - val_accuracy: 0.8357
# Epoch 6/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6417 - accuracy: 0.8280 - val_loss: 0.6916 - val_accuracy: 0.8225
# Epoch 7/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6408 - accuracy: 0.8308 - val_loss: 0.6227 - val_accuracy: 0.8471
# Epoch 8/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6308 - accuracy: 0.8345 - val_loss: 0.7167 - val_accuracy: 0.8168
# Epoch 9/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6289 - accuracy: 0.8358 - val_loss: 0.7521 - val_accuracy: 0.8079
# Epoch 10/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6264 - accuracy: 0.8376 - val_loss: 0.6466 - val_accuracy: 0.8353
# Epoch 11/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6196 - accuracy: 0.8363 - val_loss: 0.6660 - val_accuracy: 0.8325
# Epoch 12/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6206 - accuracy: 0.8386 - val_loss: 0.6037 - val_accuracy: 0.8497
# Epoch 13/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6128 - accuracy: 0.8396 - val_loss: 0.6134 - val_accuracy: 0.8463
# Epoch 14/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6100 - accuracy: 0.8429 - val_loss: 0.6838 - val_accuracy: 0.8286
# Epoch 15/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6088 - accuracy: 0.8416 - val_loss: 0.7074 - val_accuracy: 0.8222
# Epoch 16/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6104 - accuracy: 0.8425 - val_loss: 0.6715 - val_accuracy: 0.8323
# Epoch 17/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6081 - accuracy: 0.8428 - val_loss: 0.6455 - val_accuracy: 0.8353
# Epoch 18/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5975 - accuracy: 0.8463 - val_loss: 0.6792 - val_accuracy: 0.8372
# Epoch 19/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5975 - accuracy: 0.8476 - val_loss: 0.7010 - val_accuracy: 0.8233
# Epoch 20/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5943 - accuracy: 0.8482 - val_loss: 0.7144 - val_accuracy: 0.8267
# Epoch 21/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5925 - accuracy: 0.8493 - val_loss: 0.7001 - val_accuracy: 0.8264
# Epoch 22/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5898 - accuracy: 0.8498 - val_loss: 0.7398 - val_accuracy: 0.8206
# Epoch 00022: early stopping

# %%
cifar10_c1f3.evaluate(X_test, y_test, batch_size = 100)
# Out:
# 100/100 [==============================] - 1s 5ms/step - loss: 2.3091 - accuracy: 0.0789
# [2.3090670108795166, 0.07890000194311142]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar_c1f3

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### cifar10 C1F3 Best Model
# - cifar10_c1f3_best_weights.045-0.8711.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c1f3_best_weights.012-0.8497.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 16ms/step - loss: 0.6037 - accuracy: 0.8497
# [0.6037348508834839, 0.8496999740600586]

# %% [markdown]
# ## **CNN2 + FCN2**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f2 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),kernel_size=(3,3),strides=(1,1),filters= 64,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(kernel_size=(3,3),strides=(1,1),filters= 32,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)        1792
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 32)        18464
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_5 (Dense)             (None, 128)               262272
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 283,818
# Trainable params: 283,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f2_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)    # patience=10, 20, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 54s 52ms/step - loss: 0.6136 - accuracy: 0.8396 - val_loss: 0.7487 - val_accuracy: 0.8154
# Epoch 2/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6125 - accuracy: 0.8425 - val_loss: 0.7452 - val_accuracy: 0.8133
# Epoch 3/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6057 - accuracy: 0.8428 - val_loss: 0.6437 - val_accuracy: 0.8418
# Epoch 4/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6039 - accuracy: 0.8451 - val_loss: 0.6250 - val_accuracy: 0.8475
# Epoch 5/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6028 - accuracy: 0.8468 - val_loss: 0.6117 - val_accuracy: 0.8526
# Epoch 6/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.6010 - accuracy: 0.8438 - val_loss: 0.6408 - val_accuracy: 0.8402
# Epoch 7/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.6041 - accuracy: 0.8443 - val_loss: 0.6608 - val_accuracy: 0.8364
# Epoch 8/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5942 - accuracy: 0.8482 - val_loss: 0.6760 - val_accuracy: 0.8321
# Epoch 9/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5894 - accuracy: 0.8486 - val_loss: 0.6233 - val_accuracy: 0.8431
# Epoch 10/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5899 - accuracy: 0.8499 - val_loss: 0.6135 - val_accuracy: 0.8475
# Epoch 11/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5901 - accuracy: 0.8496 - val_loss: 0.6709 - val_accuracy: 0.8380
# Epoch 12/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5918 - accuracy: 0.8493 - val_loss: 0.6469 - val_accuracy: 0.8401
# Epoch 13/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5819 - accuracy: 0.8527 - val_loss: 0.6160 - val_accuracy: 0.8444
# Epoch 14/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5866 - accuracy: 0.8509 - val_loss: 0.6260 - val_accuracy: 0.8460
# Epoch 15/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5779 - accuracy: 0.8536 - val_loss: 0.7275 - val_accuracy: 0.8226
# Epoch 00015: early stopping

# %%
cifar10_c2f2.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3077 - accuracy: 0.1027
# [2.307710647583008, 0.10270000249147415]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f2_best_weights.013-0.8798.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f2_best_weights.005-0.8526.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 15ms/step - loss: 0.6117 - accuracy: 0.8526
# [0.6116650104522705, 0.8525999784469604]

# %% [markdown]
# ## **CNN2 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f3 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 32, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(64, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_7 (Dense)             (None, 128)               524416
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 552,714
# Trainable params: 552,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f3_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 53s 52ms/step - loss: 0.5975 - accuracy: 0.8460 - val_loss: 0.5861 - val_accuracy: 0.8631
# Epoch 2/500
# 1000/1000 [==============================] - 54s 53ms/step - loss: 0.5984 - accuracy: 0.8465 - val_loss: 0.6098 - val_accuracy: 0.8530
# Epoch 3/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5955 - accuracy: 0.8459 - val_loss: 0.6052 - val_accuracy: 0.8531
# Epoch 4/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5935 - accuracy: 0.8467 - val_loss: 0.5751 - val_accuracy: 0.8630
# Epoch 5/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5865 - accuracy: 0.8510 - val_loss: 0.5793 - val_accuracy: 0.8559
# Epoch 6/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5894 - accuracy: 0.8510 - val_loss: 0.5966 - val_accuracy: 0.8566
# Epoch 7/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5864 - accuracy: 0.8506 - val_loss: 0.6916 - val_accuracy: 0.8325
# Epoch 8/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5822 - accuracy: 0.8540 - val_loss: 0.5826 - val_accuracy: 0.8579
# Epoch 9/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5822 - accuracy: 0.8517 - val_loss: 0.6236 - val_accuracy: 0.8463
# Epoch 10/500
# 1000/1000 [==============================] - 55s 54ms/step - loss: 0.5798 - accuracy: 0.8534 - val_loss: 0.6023 - val_accuracy: 0.8538
# Epoch 11/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5780 - accuracy: 0.8537 - val_loss: 0.5827 - val_accuracy: 0.8565
# Epoch 00011: early stopping

# %%
cifar10_c2f3.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 5ms/step - loss: 2.3041 - accuracy: 0.1131
# [2.3041036128997803, 0.11309999972581863]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2_Daug

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
# vacc_list[np.argmax(np.array(vacc_list))]
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f3_Daug_best_weights.010-0.8787.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f3_Daug_best_weights.001-0.8631.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 15ms/step - loss: 0.5861 - accuracy: 0.8631
# [0.5860643982887268, 0.863099992275238]

# %% [markdown]
# ## **CNN4 + FCN5**

# %%
##여기서 부터!!! 다시
cifar10_c4f5 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3), filters= 64, kernel_size=(3,3),strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 128, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 256, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 512, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))                                 # 5번동안 더 높은 값이 나오지 않아서 stop
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 53s 52ms/step - loss: 0.5997 - accuracy: 0.8458 - val_loss: 0.6795 - val_accuracy: 0.8284
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5922 - accuracy: 0.8475 - val_loss: 0.7616 - val_accuracy: 0.8093
# Epoch 3/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5934 - accuracy: 0.8485 - val_loss: 0.6752 - val_accuracy: 0.8337
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5900 - accuracy: 0.8494 - val_loss: 0.7698 - val_accuracy: 0.8071
# Epoch 5/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5893 - accuracy: 0.8477 - val_loss: 0.6164 - val_accuracy: 0.8467
# Epoch 6/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5814 - accuracy: 0.8523 - val_loss: 0.6815 - val_accuracy: 0.8318
# Epoch 7/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5851 - accuracy: 0.8526 - val_loss: 0.6629 - val_accuracy: 0.8386
# Epoch 8/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5814 - accuracy: 0.8532 - val_loss: 0.6538 - val_accuracy: 0.8366
# Epoch 9/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5818 - accuracy: 0.8505 - val_loss: 0.5891 - val_accuracy: 0.8522
# Epoch 10/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5811 - accuracy: 0.8525 - val_loss: 0.6392 - val_accuracy: 0.8461
# Epoch 11/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5778 - accuracy: 0.8550 - val_loss: 0.5903 - val_accuracy: 0.8562
# Epoch 12/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5757 - accuracy: 0.8535 - val_loss: 0.6342 - val_accuracy: 0.8446
# Epoch 13/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5729 - accuracy: 0.8560 - val_loss: 0.7981 - val_accuracy: 0.8040
# Epoch 14/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5745 - accuracy: 0.8544 - val_loss: 0.7264 - val_accuracy: 0.8201
# Epoch 15/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5726 - accuracy: 0.8558 - val_loss: 0.5861 - val_accuracy: 0.8624
# Epoch 16/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5676 - accuracy: 0.8568 - val_loss: 0.6123 - val_accuracy: 0.8501
# Epoch 17/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5682 - accuracy: 0.8587 - val_loss: 0.6515 - val_accuracy: 0.8468
# Epoch 18/500
# 1000/1000 [==============================] - 54s 54ms/step - loss: 0.5703 - accuracy: 0.8557 - val_loss: 0.6383 - val_accuracy: 0.8476
# Epoch 19/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5668 - accuracy: 0.8579 - val_loss: 0.6085 - val_accuracy: 0.8508
# Epoch 20/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5633 - accuracy: 0.8597 - val_loss: 0.6030 - val_accuracy: 0.8509
# Epoch 00020: early stopping

# %%
cifar10_c4f5.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 2s 9ms/step - loss: 2.3029 - accuracy: 0.1023
# [2.3028788566589355, 0.1023000031709671]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_Daug_best_weights.011-0.8562.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 3s 11ms/step - loss: 0.5903 - accuracy: 0.8562
# [0.5902919173240662, 0.8561999797821045]

# %% [markdown]
# # **c4f5 best model 구하기**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c4f5_ = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 512, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 256, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 128, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5_.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 52s 50ms/step - loss: 0.5749 - accuracy: 0.8546 - val_loss: 0.6367 - val_accuracy: 0.8510
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5771 - accuracy: 0.8528 - val_loss: 0.6603 - val_accuracy: 0.8427
# Epoch 3/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5742 - accuracy: 0.8551 - val_loss: 0.5860 - val_accuracy: 0.8642
# Epoch 4/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5726 - accuracy: 0.8552 - val_loss: 0.6335 - val_accuracy: 0.8461
# Epoch 5/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5758 - accuracy: 0.8545 - val_loss: 0.5932 - val_accuracy: 0.8567
# Epoch 6/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5656 - accuracy: 0.8586 - val_loss: 0.7319 - val_accuracy: 0.8225
# Epoch 7/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5710 - accuracy: 0.8546 - val_loss: 0.6540 - val_accuracy: 0.8462
# Epoch 8/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5647 - accuracy: 0.8594 - val_loss: 0.6535 - val_accuracy: 0.8400
# Epoch 00008: early stopping

# %%
cifar10_c4f5_.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 5s 19ms/step - loss: 2.3022 - accuracy: 0.1296
# [2.3022043704986572, 0.12960000336170197]

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_Daug_best_weights.008-0.8762.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_Daug_best_weights.015-0.8624.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5861 - accuracy: 0.8624
# [0.5861172080039978, 0.8623999953269958]

# %% [markdown]
# #** 결과 비교 **

# %%
result = [[0.6552643179893494, 0.8366000056266785], 
 [0.5090670108795166, 0.78900000194311142], 
 [0.5393686294555664, 0.879800021648407], 
[0.519992470741272, 0.8762000203132629],
 [0.49226030707359314, 0.8902999758720398]]

# %%
accuracy = [row[1] for row in result]
accuracy
# Out:
# [0.8366000056266785,
#  0.7890000019431114,
#  0.879800021648407,
#  0.8762000203132629,
#  0.8902999758720398]

# %%
x = np.arange(5)
models = ['cifar10_Daug','cifar10_c1f3','cifar10_c2f2','cifar10_c4f5_Daug','cifar_c4f5']
accuracies = [acc*100 for acc in accuracy] # %

plt.figure(figsize=(10,5))
plt.bar(x, accuracies)
plt.xticks(x, models)
plt.show()

# %% [markdown]
# ## 모형의 저장
#
# - 트레이닝이 끝난 모형은 save 메서드로 가중치와 함께 hdf5 형식으로 저장
# - load 명령으로 불러 사용

# %% [markdown]
# ### Best Daug model
# - cifar10_Daug_best_weights.013-0.8025.hdf5
# - cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5
# ### Best c4f5 model of cifar10
# - cifar10_c4f5_best_weights.002-0.8903.hdf5

# %%
from keras.models import load_model

model_best = load_model('cifar10_c4f5_best_weights.003-0.8642.hdf5')
model_best.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5860 - accuracy: 0.8642
# [0.5860351920127869, 0.8641999959945679]

# %% [markdown]
# ---

# %%
from sklearn.metrics import confusion_matrix

predictions = model_best.predict(X_test)
predictions0 = np.argmax(predictions, axis=1)
cm = confusion_matrix(y_test0, predictions0)

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=class_names, yticklabels=class_names, fmt='d', annot=True, cmap=plt.cm.coolwarm)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix', fontsize=20)
plt.show()

# %% [markdown]
# ---
